# %%
#also known as half interval search
#finds target value within a sorted array if not sorted one needs to sort it.
#sort array first.


array = [5,6,0,1,5,6,3]
def quicksort(array):
    if(len(array)==0):
        return []
    left_elements = []
    right_elements = []
    pivot = array[0]
    
    for i in array:
        if i < pivot:
            left_elements.append(i)
        elif i > pivot:
            right_elements.append(i)
    return quicksort(left_elements)+[pivot]+quicksort(right_elements)

# if __name__ == '__main__':
#     array = [12, 11, 15, 10, 9, 1, 2, 3, 13, 14, 4, 5, 6, 7, 8]
#     quicksort(array, 0, len(array) - 1)
#     print(array)
#create a function that takes in an array, a the size of it and a target.
#start base case
#Find if the element exists
'''Have pointers of start to represent the starting 
and end to represent the end of array for the flow of direction. 

Then find the mid of the array
If mid element is equal to element, return mid
If mid is less element, remove left side, start = mid+1
If mid is more than an element, remove right side, end = mid -1
Repeat the process n times till you find the position of the element'''
def  binary_search(arr,target,start,end):
    start = 0
    end = len(arr) - 1
    mid = start - end /2
    if start <= end:
        mid = start + (start+end) //2
        if arr[mid] == target:
            return mid
        elif(arr[mid] < target) :
            return binary_search(arr,target,mid + 1,end)
        else:
            return binary_search(arr,target,start,end = mid - 1)
        
    else:
        return 'not found'
print(binary_search([3,4,5,6,76],5,0,len([3,4,5,6,76])-1))
# Out:
# 2

# %%
#also known as half interval search
#finds target value within a sorted array if not sorted one needs to sort it.
#sort array first.


array = [5,6,0,1,5,6,3]
def quicksort(array):
    if(len(array)==0):
        return []
    left_elements = []
    right_elements = []
    pivot = array[0]
    
    for i in array:
        if i < pivot:
            left_elements.append(i)
        elif i > pivot:
            right_elements.append(i)
    return quicksort(left_elements)+[pivot]+quicksort(right_elements)

# if __name__ == '__main__':
#     array = [12, 11, 15, 10, 9, 1, 2, 3, 13, 14, 4, 5, 6, 7, 8]
#     quicksort(array, 0, len(array) - 1)
#     print(array)
#create a function that takes in an array, a the size of it and a target.
#start base case
#Find if the element exists
'''Have pointers of start to represent the starting 
and end to represent the end of array for the flow of direction. 

Then find the mid of the array
If mid element is equal to element, return mid
If mid is less element, remove left side, start = mid+1
If mid is more than an element, remove right side, end = mid -1
Repeat the process n times till you find the position of the element'''
def  binary_search(arr,target,start,end):
    start = 0
    end = len(arr) - 1
    mid = start - end /2
    if start <= end:
        mid = start + (start+end) //2
        if arr[mid] == target:
            return mid
        elif(arr[mid] < target) :
            return binary_search(arr,target,mid + 1,end)
        else:
            return binary_search(arr,target,start,end = mid - 1)
        
    else:
        return 'not found'
print(binary_search([3,4,56,5,6,76],5,0,len([3,4,5,6,76])-1))
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# /home/shamim/Documents/Linkedlist/binary_search.py in line 51
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=48'>49</a>     else:
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=49'>50</a>         return 'not found'
# ---> <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=50'>51</a> print(binary_search([3,4,56,5,6,76],5,0,len([3,4,5,6,76])-1))
#
# /home/shamim/Documents/Linkedlist/binary_search.py in line 47, in binary_search(arr, target, start, end)
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=44'>45</a>         return binary_search(arr,target,mid + 1,end)
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=45'>46</a>     else:
# ---> <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=46'>47</a>         return binary_search(arr,target,start,end = mid - 1)
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=48'>49</a> else:
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=49'>50</a>     return 'not found'
#
# /home/shamim/Documents/Linkedlist/binary_search.py in line 47, in binary_search(arr, target, start, end)
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=44'>45</a>         return binary_search(arr,target,mid + 1,end)
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=45'>46</a>     else:
# ---> <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=46'>47</a>         return binary_search(arr,target,start,end = mid - 1)
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=48'>49</a> else:
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=49'>50</a>     return 'not found'
#
#     [... skipping similar frames: binary_search at line 47 (2968 times)]
#
# /home/shamim/Documents/Linkedlist/binary_search.py in line 47, in binary_search(arr, target, start, end)
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=44'>45</a>         return binary_search(arr,target,mid + 1,end)
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=45'>46</a>     else:
# ---> <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=46'>47</a>         return binary_search(arr,target,start,end = mid - 1)
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=48'>49</a> else:
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=49'>50</a>     return 'not found'
#
# /home/shamim/Documents/Linkedlist/binary_search.py in line 38, in binary_search(arr, target, start, end)
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=35'>36</a> def  binary_search(arr,target,start,end):
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=36'>37</a>     start = 0
# ---> <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=37'>38</a>     end = len(arr) - 1
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=38'>39</a>     mid = start - end /2
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=39'>40</a>     if start <= end:
#
# RecursionError: maximum recursion depth exceeded while calling a Python object

# %%
#also known as half interval search
#finds target value within a sorted array if not sorted one needs to sort it.
#sort array first.


array = [5,6,0,1,5,6,3]
def quicksort(array):
    if(len(array)==0):
        return []
    left_elements = []
    right_elements = []
    pivot = array[0]
    
    for i in array:
        if i < pivot:
            left_elements.append(i)
        elif i > pivot:
            right_elements.append(i)
    return quicksort(left_elements)+[pivot]+quicksort(right_elements)

# if __name__ == '__main__':
#     array = [12, 11, 15, 10, 9, 1, 2, 3, 13, 14, 4, 5, 6, 7, 8]
#     quicksort(array, 0, len(array) - 1)
#     print(array)
#create a function that takes in an array, a the size of it and a target.
#start base case
#Find if the element exists
'''Have pointers of start to represent the starting 
and end to represent the end of array for the flow of direction. 

Then find the mid of the array
If mid element is equal to element, return mid
If mid is less element, remove left side, start = mid+1
If mid is more than an element, remove right side, end = mid -1
Repeat the process n times till you find the position of the element'''
def  binary_search(arr,target,start,end):
    start = 0
    end = len(arr) - 1
    mid = start - end /2
    if start <= end:
        mid = start + (start+end) //2
        if arr[mid] == target:
            return mid
        elif(arr[mid] < target) :
            return binary_search(arr,target,mid + 1,end)
        else:
            return binary_search(arr,target,start,end = mid - 1)
        
    else:
        return 'not found'
array = [3,4,56,5,6,76]
print(binary_search(array,5,0,len(array)-1))
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# /home/shamim/Documents/Linkedlist/binary_search.py in line 52
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=49'>50</a>         return 'not found'
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=50'>51</a> array = [3,4,56,5,6,76]
# ---> <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=51'>52</a> print(binary_search(array,5,0,len(array)-1))
#
# /home/shamim/Documents/Linkedlist/binary_search.py in line 47, in binary_search(arr, target, start, end)
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=44'>45</a>         return binary_search(arr,target,mid + 1,end)
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=45'>46</a>     else:
# ---> <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=46'>47</a>         return binary_search(arr,target,start,end = mid - 1)
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=48'>49</a> else:
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=49'>50</a>     return 'not found'
#
# /home/shamim/Documents/Linkedlist/binary_search.py in line 47, in binary_search(arr, target, start, end)
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=44'>45</a>         return binary_search(arr,target,mid + 1,end)
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=45'>46</a>     else:
# ---> <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=46'>47</a>         return binary_search(arr,target,start,end = mid - 1)
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=48'>49</a> else:
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=49'>50</a>     return 'not found'
#
#     [... skipping similar frames: binary_search at line 47 (2968 times)]
#
# /home/shamim/Documents/Linkedlist/binary_search.py in line 47, in binary_search(arr, target, start, end)
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=44'>45</a>         return binary_search(arr,target,mid + 1,end)
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=45'>46</a>     else:
# ---> <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=46'>47</a>         return binary_search(arr,target,start,end = mid - 1)
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=48'>49</a> else:
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=49'>50</a>     return 'not found'
#
# /home/shamim/Documents/Linkedlist/binary_search.py in line 38, in binary_search(arr, target, start, end)
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=35'>36</a> def  binary_search(arr,target,start,end):
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=36'>37</a>     start = 0
# ---> <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=37'>38</a>     end = len(arr) - 1
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=38'>39</a>     mid = start - end /2
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=39'>40</a>     if start <= end:
#
# RecursionError: maximum recursion depth exceeded while calling a Python object

# %%
#also known as half interval search
#finds target value within a sorted array if not sorted one needs to sort it.
#sort array first.


array = [5,6,0,1,5,6,3]
def quicksort(array):
    if(len(array)==0):
        return []
    left_elements = []
    right_elements = []
    pivot = array[0]
    
    for i in array:
        if i < pivot:
            left_elements.append(i)
        elif i > pivot:
            right_elements.append(i)
    return quicksort(left_elements)+[pivot]+quicksort(right_elements)

# if __name__ == '__main__':
#     array = [12, 11, 15, 10, 9, 1, 2, 3, 13, 14, 4, 5, 6, 7, 8]
#     quicksort(array, 0, len(array) - 1)
#     print(array)
#create a function that takes in an array, a the size of it and a target.
#start base case
#Find if the element exists
'''Have pointers of start to represent the starting 
and end to represent the end of array for the flow of direction. 

Then find the mid of the array
If mid element is equal to element, return mid
If mid is less element, remove left side, start = mid+1
If mid is more than an element, remove right side, end = mid -1
Repeat the process n times till you find the position of the element'''
def  binary_search(arr,target,start,end):

    if start <= end:
        mid = start + (start+end) //2
        if arr[mid] == target:
            return mid
        elif(arr[mid] < target) :
            return binary_search(arr,target,mid + 1,end)
        else:
            return binary_search(arr,target,start,end = mid - 1)
        
    else:
        return 'not found'
array = [3,4,56,5,6,76]
print(binary_search(array,5,0,len(array)-1))
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# /home/shamim/Documents/Linkedlist/binary_search.py in line 50
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=47'>48</a>         return 'not found'
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=48'>49</a> array = [3,4,56,5,6,76]
# ---> <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=49'>50</a> print(binary_search(array,5,0,len(array)-1))
#
# /home/shamim/Documents/Linkedlist/binary_search.py in line 45, in binary_search(arr, target, start, end)
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=42'>43</a>         return binary_search(arr,target,mid + 1,end)
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=43'>44</a>     else:
# ---> <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=44'>45</a>         return binary_search(arr,target,start,end = mid - 1)
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=46'>47</a> else:
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=47'>48</a>     return 'not found'
#
# /home/shamim/Documents/Linkedlist/binary_search.py in line 43, in binary_search(arr, target, start, end)
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=40'>41</a>     return mid
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=41'>42</a> elif(arr[mid] < target) :
# ---> <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=42'>43</a>     return binary_search(arr,target,mid + 1,end)
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=43'>44</a> else:
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=44'>45</a>     return binary_search(arr,target,start,end = mid - 1)
#
# /home/shamim/Documents/Linkedlist/binary_search.py in line 45, in binary_search(arr, target, start, end)
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=42'>43</a>         return binary_search(arr,target,mid + 1,end)
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=43'>44</a>     else:
# ---> <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=44'>45</a>         return binary_search(arr,target,start,end = mid - 1)
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=46'>47</a> else:
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=47'>48</a>     return 'not found'
#
# /home/shamim/Documents/Linkedlist/binary_search.py in line 45, in binary_search(arr, target, start, end)
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=42'>43</a>         return binary_search(arr,target,mid + 1,end)
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=43'>44</a>     else:
# ---> <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=44'>45</a>         return binary_search(arr,target,start,end = mid - 1)
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=46'>47</a> else:
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=47'>48</a>     return 'not found'
#
#     [... skipping similar frames: binary_search at line 45 (2966 times)]
#
# /home/shamim/Documents/Linkedlist/binary_search.py in line 45, in binary_search(arr, target, start, end)
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=42'>43</a>         return binary_search(arr,target,mid + 1,end)
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=43'>44</a>     else:
# ---> <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=44'>45</a>         return binary_search(arr,target,start,end = mid - 1)
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=46'>47</a> else:
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=47'>48</a>     return 'not found'
#
# /home/shamim/Documents/Linkedlist/binary_search.py in line 38, in binary_search(arr, target, start, end)
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=35'>36</a> def  binary_search(arr,target,start,end):
# ---> <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=37'>38</a>     if start <= end:
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=38'>39</a>         mid = start + (start+end) //2
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=39'>40</a>         if arr[mid] == target:
#
# RecursionError: maximum recursion depth exceeded in comparison

# %%
#also known as half interval search
#finds target value within a sorted array if not sorted one needs to sort it.
#sort array first.


array = [5,6,0,1,5,6,3]
def quicksort(array):
    if(len(array)==0):
        return []
    left_elements = []
    right_elements = []
    pivot = array[0]
    
    for i in array:
        if i < pivot:
            left_elements.append(i)
        elif i > pivot:
            right_elements.append(i)
    return quicksort(left_elements)+[pivot]+quicksort(right_elements)

# if __name__ == '__main__':
#     array = [12, 11, 15, 10, 9, 1, 2, 3, 13, 14, 4, 5, 6, 7, 8]
#     quicksort(array, 0, len(array) - 1)
#     print(array)
#create a function that takes in an array, a the size of it and a target.
#start base case
#Find if the element exists
'''Have pointers of start to represent the starting 
and end to represent the end of array for the flow of direction. 

Then find the mid of the array
If mid element is equal to element, return mid
If mid is less element, remove left side, start = mid+1
If mid is more than an element, remove right side, end = mid -1
Repeat the process n times till you find the position of the element'''
def  binary_search(arr,target,start,end):

    if start <= end:
        mid = start + (start+end) //2
        if arr[mid] == target:
            return mid
        elif(arr[mid] < target) :
            return binary_search(arr,target,mid + 1,end)
        else:
            return binary_search(arr,target,start,end = mid - 1)
        
    else:
        return 'not found'
array = [3,4,5,6,76]
print(binary_search(array,5,0,len(array)-1))
# Out:
# 2

# %%
#also known as half interval search
#finds target value within a sorted array if not sorted one needs to sort it.
#sort array first.


array = [5,6,0,1,5,6,3]
def quicksort(array):
    if(len(array)==0):
        return []
    left_elements = []
    right_elements = []
    pivot = array[0]
    
    for i in array:
        if i < pivot:
            left_elements.append(i)
        elif i > pivot:
            right_elements.append(i)
    return quicksort(left_elements)+[pivot]+quicksort(right_elements)

# if __name__ == '__main__':
#     array = [12, 11, 15, 10, 9, 1, 2, 3, 13, 14, 4, 5, 6, 7, 8]
#     quicksort(array, 0, len(array) - 1)
#     print(array)
#create a function that takes in an array, a the size of it and a target.
#start base case
#Find if the element exists
'''Have pointers of start to represent the starting 
and end to represent the end of array for the flow of direction. 

Then find the mid of the array
If mid element is equal to element, return mid
If mid is less element, remove left side, start = mid+1
If mid is more than an element, remove right side, end = mid -1
Repeat the process n times till you find the position of the element'''
def  binary_search(arr,target,start,end):

    if start <= end:
        mid = start + (start+end) //2
        if arr[mid] == target:
            return mid
        elif(arr[mid] < target) :
            return binary_search(arr,target,mid + 1,end)
        else:
            return binary_search(arr,target,start,end = mid - 1)
        
    else:
        return 'not found'
array = [3,5,6,76]
print(binary_search(array,5,0,len(array)-1))
# Out:
# 1

# %%
#also known as half interval search
#finds target value within a sorted array if not sorted one needs to sort it.
#sort array first.


array = [5,6,0,1,5,6,3]
def quicksort(array):
    if(len(array)==0):
        return []
    left_elements = []
    right_elements = []
    pivot = array[0]
    
    for i in array:
        if i < pivot:
            left_elements.append(i)
        elif i > pivot:
            right_elements.append(i)
    return quicksort(left_elements)+[pivot]+quicksort(right_elements)

# if __name__ == '__main__':
#     array = [12, 11, 15, 10, 9, 1, 2, 3, 13, 14, 4, 5, 6, 7, 8]
#     quicksort(array, 0, len(array) - 1)
#     print(array)
#create a function that takes in an array, a the size of it and a target.
#start base case
#Find if the element exists
'''Have pointers of start to represent the starting 
and end to represent the end of array for the flow of direction. 

Then find the mid of the array
If mid element is equal to element, return mid
If mid is less element, remove left side, start = mid+1
If mid is more than an element, remove right side, end = mid -1
Repeat the process n times till you find the position of the element'''
def  binary_search(arr,target,start,end):

    if start <= end:
        mid = start + (start+end) //2
        if arr[mid] == target:
            return mid
        elif(arr[mid] < target) :
            return binary_search(arr,target,mid + 1,end)
        else:
            return binary_search(arr,target,start,end = mid - 1)
        
    else:
        return 'not found'
array = [3,4,67,5,6,76]
print(binary_search(array,5,0,len(array)-1))
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# /home/shamim/Documents/Linkedlist/binary_search.py in line 50
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=47'>48</a>         return 'not found'
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=48'>49</a> array = [3,4,67,5,6,76]
# ---> <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=49'>50</a> print(binary_search(array,5,0,len(array)-1))
#
# /home/shamim/Documents/Linkedlist/binary_search.py in line 45, in binary_search(arr, target, start, end)
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=42'>43</a>         return binary_search(arr,target,mid + 1,end)
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=43'>44</a>     else:
# ---> <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=44'>45</a>         return binary_search(arr,target,start,end = mid - 1)
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=46'>47</a> else:
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=47'>48</a>     return 'not found'
#
# /home/shamim/Documents/Linkedlist/binary_search.py in line 43, in binary_search(arr, target, start, end)
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=40'>41</a>     return mid
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=41'>42</a> elif(arr[mid] < target) :
# ---> <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=42'>43</a>     return binary_search(arr,target,mid + 1,end)
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=43'>44</a> else:
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=44'>45</a>     return binary_search(arr,target,start,end = mid - 1)
#
# /home/shamim/Documents/Linkedlist/binary_search.py in line 45, in binary_search(arr, target, start, end)
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=42'>43</a>         return binary_search(arr,target,mid + 1,end)
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=43'>44</a>     else:
# ---> <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=44'>45</a>         return binary_search(arr,target,start,end = mid - 1)
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=46'>47</a> else:
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=47'>48</a>     return 'not found'
#
# /home/shamim/Documents/Linkedlist/binary_search.py in line 45, in binary_search(arr, target, start, end)
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=42'>43</a>         return binary_search(arr,target,mid + 1,end)
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=43'>44</a>     else:
# ---> <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=44'>45</a>         return binary_search(arr,target,start,end = mid - 1)
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=46'>47</a> else:
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=47'>48</a>     return 'not found'
#
#     [... skipping similar frames: binary_search at line 45 (2966 times)]
#
# /home/shamim/Documents/Linkedlist/binary_search.py in line 45, in binary_search(arr, target, start, end)
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=42'>43</a>         return binary_search(arr,target,mid + 1,end)
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=43'>44</a>     else:
# ---> <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=44'>45</a>         return binary_search(arr,target,start,end = mid - 1)
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=46'>47</a> else:
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=47'>48</a>     return 'not found'
#
# /home/shamim/Documents/Linkedlist/binary_search.py in line 38, in binary_search(arr, target, start, end)
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=35'>36</a> def  binary_search(arr,target,start,end):
# ---> <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=37'>38</a>     if start <= end:
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=38'>39</a>         mid = start + (start+end) //2
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=39'>40</a>         if arr[mid] == target:
#
# RecursionError: maximum recursion depth exceeded in comparison

# %%
#also known as half interval search
#finds target value within a sorted array if not sorted one needs to sort it.
#sort array first.


array = [5,6,0,1,5,6,3]
def quicksort(array):
    if(len(array)==0):
        return []
    left_elements = []
    right_elements = []
    pivot = array[0]
    
    for i in array:
        if i < pivot:
            left_elements.append(i)
        elif i > pivot:
            right_elements.append(i)
    return quicksort(left_elements)+[pivot]+quicksort(right_elements)

# if __name__ == '__main__':
#     array = [12, 11, 15, 10, 9, 1, 2, 3, 13, 14, 4, 5, 6, 7, 8]
#     quicksort(array, 0, len(array) - 1)
#     print(array)
#create a function that takes in an array, a the size of it and a target.
#start base case
#Find if the element exists
'''Have pointers of start to represent the starting 
and end to represent the end of array for the flow of direction. 

Then find the mid of the array
If mid element is equal to element, return mid
If mid is less element, remove left side, start = mid+1
If mid is more than an element, remove right side, end = mid -1
Repeat the process n times till you find the position of the element'''
def  binary_search(arr,target,start,end):

    if start <= end:
        mid = start + (start+end) //2
        if arr[mid] == target:
            return mid
        elif(arr[mid] < target) :
            return binary_search(arr,target,mid + 1,end)
        else:
            return binary_search(arr,target,start,end = mid - 1)
        
    else:
        return 'not found'
array = [3,4,5,6,76]
print(binary_search(array,5,0,len(array)-1))
# Out:
# 2

# %%
#also known as half interval search
#finds target value within a sorted array if not sorted one needs to sort it.
#sort array first.


array = [5,6,0,1,5,6,3]
def quicksort(array):
    if(len(array)==0):
        return []
    left_elements = []
    right_elements = []
    pivot = array[0]
    
    for i in array:
        if i < pivot:
            left_elements.append(i)
        elif i > pivot:
            right_elements.append(i)
    return quicksort(left_elements)+[pivot]+quicksort(right_elements)

# if __name__ == '__main__':
#     array = [12, 11, 15, 10, 9, 1, 2, 3, 13, 14, 4, 5, 6, 7, 8]
#     quicksort(array, 0, len(array) - 1)
#     print(array)
#create a function that takes in an array, a the size of it and a target.
#start base case
#Find if the element exists
'''Have pointers of start to represent the starting 
and end to represent the end of array for the flow of direction. 

Then find the mid of the array
If mid element is equal to element, return mid
If mid is less element, remove left side, start = mid+1
If mid is more than an element, remove right side, end = mid -1
Repeat the process n times till you find the position of the element'''
def  binary_search(arr,target,start,end):

    if start <= end:
        mid = start + (start+end) //2
        if arr[mid] == target:
            return mid
        elif(arr[mid] < target) :
            return binary_search(arr,target,mid + 1,end)
        else:
            return binary_search(arr,target,start,end = mid - 1)
        
    else:
        return 'not found'
array = [3,4,5,6,76,78]
print(binary_search(array,5,0,len(array)-1))
# Out:
# 2

# %%
#also known as half interval search
#finds target value within a sorted array if not sorted one needs to sort it.
#sort array first.


array = [5,6,0,1,5,6,3]
def quicksort(array):
    if(len(array)==0):
        return []
    left_elements = []
    right_elements = []
    pivot = array[0]
    
    for i in array:
        if i < pivot:
            left_elements.append(i)
        elif i > pivot:
            right_elements.append(i)
    return quicksort(left_elements)+[pivot]+quicksort(right_elements)

# if __name__ == '__main__':
#     array = [12, 11, 15, 10, 9, 1, 2, 3, 13, 14, 4, 5, 6, 7, 8]
#     quicksort(array, 0, len(array) - 1)
#     print(array)
#create a function that takes in an array, a the size of it and a target.
#start base case
#Find if the element exists
'''Have pointers of start to represent the starting 
and end to represent the end of array for the flow of direction. 

Then find the mid of the array
If mid element is equal to element, return mid
If mid is less element, remove left side, start = mid+1
If mid is more than an element, remove right side, end = mid -1
Repeat the process n times till you find the position of the element'''
def  binary_search(arr,target,start,end):

    if start <= end:
        mid = start + (start+end) //2
        if arr[mid] == target:
            return mid
        elif(arr[mid] < target) :
            return binary_search(arr,target,mid + 1,end)
        else:
            return binary_search(arr,target,start,end = mid - 1)
        
    else:
        return 'not found'
array = [3,7,4,5,6,76,78,]
print(binary_search(array,5,0,len(array)-1))
# Out:
# 3

# %%
#also known as half interval search
#finds target value within a sorted array if not sorted one needs to sort it.
#sort array first.


array = [5,6,0,1,5,6,3]
def quicksort(array):
    if(len(array)==0):
        return []
    left_elements = []
    right_elements = []
    pivot = array[0]
    
    for i in array:
        if i < pivot:
            left_elements.append(i)
        elif i > pivot:
            right_elements.append(i)
    return quicksort(left_elements)+[pivot]+quicksort(right_elements)

# if __name__ == '__main__':
#     array = [12, 11, 15, 10, 9, 1, 2, 3, 13, 14, 4, 5, 6, 7, 8]
#     quicksort(array, 0, len(array) - 1)
#     print(array)
#create a function that takes in an array, a the size of it and a target.
#start base case
#Find if the element exists
'''Have pointers of start to represent the starting 
and end to represent the end of array for the flow of direction. 

Then find the mid of the array
If mid element is equal to element, return mid
If mid is less element, remove left side, start = mid+1
If mid is more than an element, remove right side, end = mid -1
Repeat the process n times till you find the position of the element'''
def  binary_search(arr,target,start,end):

    if start <= end:
        mid = start + (start+end) //2
        if arr[mid] == target:
            return mid
        elif(arr[mid] < target) :
            return binary_search(arr,target,mid + 1,end)
        else:
            return binary_search(arr,target,start,end = mid - 1)
        
    else:
        return 'not found'
array = [3,7,56,4,5,6,76,78,]
print(binary_search(array,5,0,len(array)-1))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /home/shamim/Documents/Linkedlist/binary_search.py in line 50
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=47'>48</a>         return 'not found'
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=48'>49</a> array = [3,7,56,4,5,6,76,78,]
# ---> <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=49'>50</a> print(binary_search(array,5,0,len(array)-1))
#
# /home/shamim/Documents/Linkedlist/binary_search.py in line 43, in binary_search(arr, target, start, end)
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=40'>41</a>     return mid
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=41'>42</a> elif(arr[mid] < target) :
# ---> <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=42'>43</a>     return binary_search(arr,target,mid + 1,end)
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=43'>44</a> else:
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=44'>45</a>     return binary_search(arr,target,start,end = mid - 1)
#
# /home/shamim/Documents/Linkedlist/binary_search.py in line 40, in binary_search(arr, target, start, end)
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=37'>38</a> if start <= end:
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=38'>39</a>     mid = start + (start+end) //2
# ---> <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=39'>40</a>     if arr[mid] == target:
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=40'>41</a>         return mid
#      <a href='file:///home/shamim/Documents/Linkedlist/binary_search.py?line=41'>42</a>     elif(arr[mid] < target) :
#
# IndexError: list index out of range

# %%
# we got the above error after adding 56 before 5, this is because binary search should be performed on a sorted array.🤩
